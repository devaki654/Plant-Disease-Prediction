# %%
import os

def total_files(folder_path):
    # Count the number of files in the folder
    num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
    return num_files

# Training files
train_files_Healthy = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Healthy"
train_files_Powdery = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Powdery"
train_files_Rust = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Rust"
train_files_bananaspot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\bananaspot"
train_files_chilispot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\chilispot"
train_files_cottonspot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\cottonspot"
train_files_Eggplantspot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Eggplantspot"
train_files_Potatospot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Potatospot"
train_files_sugarcanespot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\sugarcanespot"
train_files_Tomatospot = r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Tomatospot"

# Test files
test_files_Healthy = r"C:\Users\cuted\Desktop\Test\Test\Test\Healthy"
test_files_Powdery = r"C:\Users\cuted\Desktop\Test\Test\Test\Powdery"
test_files_Rust = r"C:\Users\cuted\Desktop\Test\Test\Test\Rust"
test_files_bananaspot = r"C:\Users\cuted\Desktop\Test\Test\Test\bananaspot"
test_files_chilispot = r"C:\Users\cuted\Desktop\Test\Test\Test\chilispot"
test_files_cottonspot = r"C:\Users\cuted\Desktop\Test\Test\Test\cottonspot"
test_files_Eggplantspot = r"C:\Users\cuted\Desktop\Test\Test\Test\Eggplantspot"
test_files_Potatospot = r"C:\Users\cuted\Desktop\Test\Test\Test\Potatospot"
test_files_sugarcanespot = r"C:\Users\cuted\Desktop\Test\Test\Test\sugarcanespot"
test_files_Tomatospot = r"C:\Users\cuted\Desktop\Test\Test\Test\Tomatospot"

# Validation files
valid_files_Healthy = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\Healthy"
valid_files_Powdery = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\Powdery"
valid_files_Rust = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\Rust"
valid_files_bananaspot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\bananaspot"
valid_files_chilispot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\chilispot"
valid_files_cottonspot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\cottonspot"
valid_files_Eggplantspot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\Eggplantspot"
valid_files_Potatospot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\Potatospot"
valid_files_sugarcanespot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\sugarcanespot"
valid_files_Tomatospot = r"C:\Users\cuted\OneDrive\Desktop\Validation\Validation\Tomatospot"

# Print the number of files in each set

# Training set
print("Number of healthy leaf images in training set:", total_files(train_files_Healthy))
print("Number of powder leaf images in training set:", total_files(train_files_Powdery))
print("Number of rusty leaf images in training set:", total_files(train_files_Rust))
print("Number of banana spot leaf images in training set:", total_files(train_files_bananaspot))
print("Number of chili spot leaf images in training set:", total_files(train_files_chilispot))
print("Number of cotton spot leaf images in training set:", total_files(train_files_cottonspot))
print("Number of eggplant spot leaf images in training set:", total_files(train_files_Eggplantspot))
print("Number of potato spot leaf images in training set:", total_files(train_files_Potatospot))
print("Number of sugarcane spot leaf images in training set:", total_files(train_files_sugarcanespot))
print("Number of tomato spot leaf images in training set:", total_files(train_files_Tomatospot))

print("========================================================")

# Test set
print("Number of healthy leaf images in test set:", total_files(test_files_Healthy))
print("Number of powder leaf images in test set:", total_files(test_files_Powdery))
print("Number of rusty leaf images in test set:", total_files(test_files_Rust))
print("Number of banana spot leaf images in test set:", total_files(test_files_bananaspot))
print("Number of chili spot leaf images in test set:", total_files(test_files_chilispot))
print("Number of cotton spot leaf images in test set:", total_files(test_files_cottonspot))
print("Number of eggplant spot leaf images in test set:", total_files(test_files_Eggplantspot))
print("Number of potato spot leaf images in test set:", total_files(test_files_Potatospot))
print("Number of sugarcane spot leaf images in test set:", total_files(test_files_sugarcanespot))
print("Number of tomato spot leaf images in test set:", total_files(test_files_Tomatospot))

print("========================================================")

# Validation set
print("Number of healthy leaf images in validation set:", total_files(valid_files_Healthy))
print("Number of powder leaf images in validation set:", total_files(valid_files_Powdery))
print("Number of rusty leaf images in validation set:", total_files(valid_files_Rust))
print("Number of banana spot leaf images in validation set:", total_files(valid_files_bananaspot))
print("Number of chili spot leaf images in validation set:", total_files(valid_files_chilispot))
print("Number of cotton spot leaf images in validation set:", total_files(valid_files_cottonspot))
print("Number of eggplant spot leaf images in validation set:", total_files(valid_files_Eggplantspot))
print("Number of potato spot leaf images in validation set:", total_files(valid_files_Potatospot))
print("Number of sugarcane spot leaf images in validation set:", total_files(valid_files_sugarcanespot))
print("Number of tomato spot leaf images in validation set:", total_files(valid_files_Tomatospot))
# Out:
# Number of healthy leaf images in training set: 0
# Number of powder leaf images in training set: 0
# Number of rusty leaf images in training set: 0
# Number of banana spot leaf images in training set: 0
# Number of chili spot leaf images in training set: 0
# Number of cotton spot leaf images in training set: 0
# Number of eggplant spot leaf images in training set: 0
# Number of potato spot leaf images in training set: 0
# Number of sugarcane spot leaf images in training set: 0
# Number of tomato spot leaf images in training set: 0
# ...
# Number of healthy leaf images in test set: 51
# Number of powder leaf images in test set: 50
# Number of rusty leaf images in test set: 51
# Number of banana spot leaf images in test set: 221
# Number of chili spot leaf images in test set: 31
# Number of cotton spot leaf images in test set: 555
# Number of eggplant spot leaf images in test set: 286
# Number of potato spot leaf images in test set: 99
# Number of sugarcane spot leaf images in test set: 454
# ...

# %%
from PIL import Image
import IPython.display as display

image_path = r"C:\Users\cuted\Desktop\Train\Train\cottonspot\bact39.jpg"

if os.path.exists(image_path):
    with open(image_path, 'rb') as f:
        display.display(display.Image(data=f.read(), width=500))
else:
    print("File not found.")

# %%
image_path = r"C:\Users\cuted\Desktop\Train\Train\cottonspot\bact39.jpg"
with open(image_path, 'rb') as f:
    display.display(display.Image(data=f.read(), width=500))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an ImageDataGenerator for training with augmentation
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# Create an ImageDataGenerator for testing with only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    r"C:\Users\cuted\Desktop\Train\Train",  # Ensure the path is correct
    target_size=(224, 224),  # Resize to the appropriate size for pre-trained models
    batch_size=16,
    class_mode='categorical'
)

validation_generator = valid_datagen.flow_from_directory(
    r"C:\Users\cuted\Desktop\Validation\Validation\Validation",
    target_size=(224, 224),  # Match the input size expected by the model
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 1869 images belonging to 10 classes.
# Found 1869 images belonging to 10 classes.

# %%
print("Train generator batches:", len(train_generator))
print("Validation generator batches:", len(validation_generator))
# Out:
# Train generator batches: 117
# Validation generator batches: 117

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

# Load pre-trained MobileNetV2 model without the top layer (for transfer learning)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the base model to avoid training them
base_model.trainable = False

# Define the model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(1024, activation='relu'),
    layers.Dense(10, activation='softmax')  # Assuming you have 10 classes
])

# Print the model summary
model.summary()
# Out:
# ...
# 9406464/9406464 [==============================] - 3s 0us/step
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense_9 (Dense)             (None, 1024)              1311744
#
#  dense_10 (Dense)            (None, 10)                10250
#
# ...
# Total params: 3,579,978
# Trainable params: 1,321,994
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',  # Use categorical_crossentropy for multi-class classification
              metrics=['accuracy'])

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

# Load pre-trained MobileNetV2 model without the top layer (for transfer learning)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of the base model to avoid training them
base_model.trainable = False

# Define the model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(1024, activation='relu'),
    layers.Dense(10, activation='softmax')  # Assuming you have 10 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',  # Use categorical_crossentropy for multi-class classification
              metrics=['accuracy'])

# Print the model summary
model.summary()

# Now, you can train the model
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator,
    validation_batch_size=16
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_11 (Dense)            (None, 1024)              1311744
#
#  dense_12 (Dense)            (None, 10)                10250
#
# ...
# Total params: 3,579,978
# Trainable params: 1,321,994
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Epoch 1/10
# 117/117 [==============================] - 228s 2s/step - loss: 0.3023 - accuracy: 0.9160 - val_loss: 0.0839 - val_accuracy: 0.9770
# Epoch 2/10
# 117/117 [==============================] - 186s 2s/step - loss: 0.0386 - accuracy: 0.9861 - val_loss: 0.0673 - val_accuracy: 0.9861
# Epoch 3/10
# ...

# %%
# Evaluate the model on the validation set
validation_loss, validation_accuracy = model.evaluate(validation_generator)

print(f"Validation Loss: {validation_loss}")
print(f"Validation Accuracy: {validation_accuracy}")
# Out:
# 117/117 [==============================] - 82s 695ms/step - loss: 1.7642e-04 - accuracy: 1.0000
# Validation Loss: 0.0001764171611284837
# Validation Accuracy: 1.0

# %%
#3: Fine-Tuning (Optional)
# Unfreeze some layers of the base model (e.g., the last few layers)
base_model.trainable = True
fine_tune_at = 100  # Unfreeze layers after the 100th layer
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

# Recompile the model to apply changes
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Use a smaller learning rate for fine-tuning
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Fine-tune the model
history_fine_tune = model.fit(
    train_generator,
    epochs=5,  # Fine-tune for a few more epochs
    validation_data=validation_generator,
    validation_batch_size=16
)

# %%
model.save('modell.keras')

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load a new image
img_path = r"C:\Users\cuted\Desktop\Test\Test\Test\Healthy\8e7e70a6878c1c79.jpg"  # Replace with the path to the image you want to predict
img = image.load_img(img_path, target_size=(224, 224))  # Resize the image to the model's input size
img_array = image.img_to_array(img)  # Convert the image to a numpy array
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Make a prediction
prediction = model.predict(img_array)

# Get the class with the highest probability
predicted_class = np.argmax(prediction, axis=1)

# Print the predicted class (assuming you know the class labels)
class_labels = ['Healthy', 'Powdery', 'Rust', 'BananaSpot', 'ChiliSpot', 'CottonSpot', 'EggplantSpot', 'PotatoSpot', 'SugarcaneSpot', 'TomatoSpot']
print(f"Predicted Class: {class_labels[predicted_class[0]]}")
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted Class: SugarcaneSpot

# %%
model.save('')

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import seaborn as sns
sns.set_theme()
sns.set_context("poster")

figure(figsize=(25, 25), dpi=100)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.save("model.keras")

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np

def preprocess_image(image_path, target_size=(225, 225)):
    img = load_img(image_path, target_size=target_size)
    x = img_to_array(img)
    x = x.astype('float32') / 255.
    x = np.expand_dims(x, axis=0)
    return x

x = preprocess_image(r"C:\Users\cuted\OneDrive\Desktop\Train\Train\Rust\9894ad9bae345365.jpg")

# %%
predictions = model.predict(x)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# array([2.006867e-06, 7.917571e-05, 9.999188e-01], dtype=float32)

# %%
labels = train_generator.class_indices
labels = {v: k for k, v in labels.items()}
labels
# Out:
# {0: 'Healthy', 1: 'Powdery', 2: 'Rust'}

# %%
predicted_label = labels[np.argmax(predictions)]
print(predicted_label)
# Out:
# Rust
